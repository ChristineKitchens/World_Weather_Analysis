# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.        
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                          
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | norman wells
# Processing Record 4 of Set 1 | morehead
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | mayo
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | hay river
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | bloemfontein
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | fare
# Processing Record 18 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | pitimbu
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | junction city
# Processing Record 24 of Set 1 | maragogi
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | nisia floresta
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | amuntai
# Processing Record 31 of Set 1 | codrington
# Processing Record 32 of Set 1 | inirida
# Processing Record 33 of Set 1 | nantucket
# Processing Record 34 of Set 1 | mayumba
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | makrikapa
# City not found. Skipping...
# Processing Record 37 of Set 1 | portland
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | rio gallegos
# Processing Record 41 of Set 1 | puerto escondido
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | big spring
# Processing Record 44 of Set 1 | awjilah
# Processing Record 45 of Set 1 | ostersund
# Processing Record 46 of Set 1 | sinnamary
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | santiago de chuco
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | sitka
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | ancud
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | drayton valley
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | marzuq
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | fort nelson
# Processing Record 18 of Set 2 | broome
# Processing Record 19 of Set 2 | izumo
# Processing Record 20 of Set 2 | khani
# Processing Record 21 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | benjamin aceval
# Processing Record 24 of Set 2 | seoul
# Processing Record 25 of Set 2 | mandera
# Processing Record 26 of Set 2 | koumac
# Processing Record 27 of Set 2 | malm
# Processing Record 28 of Set 2 | severo-kurilsk
# Processing Record 29 of Set 2 | kirakira
# Processing Record 30 of Set 2 | tual
# Processing Record 31 of Set 2 | san luis
# Processing Record 32 of Set 2 | khovu-aksy
# Processing Record 33 of Set 2 | trairi
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | ust-uda
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | koungou
# Processing Record 40 of Set 2 | paamiut
# Processing Record 41 of Set 2 | kahului
# Processing Record 42 of Set 2 | nakasongola
# Processing Record 43 of Set 2 | nogent-le-rotrou
# Processing Record 44 of Set 2 | port augusta
# Processing Record 45 of Set 2 | hofn
# Processing Record 46 of Set 2 | kecel
# Processing Record 47 of Set 2 | bukachacha
# Processing Record 48 of Set 2 | grootfontein
# Processing Record 49 of Set 2 | puerto madryn
# Processing Record 50 of Set 2 | acarau
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | nome
# Processing Record 9 of Set 3 | khislavichi
# Processing Record 10 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | high level
# Processing Record 13 of Set 3 | itacoatiara
# Processing Record 14 of Set 3 | pasighat
# Processing Record 15 of Set 3 | bredasdorp
# Processing Record 16 of Set 3 | port antonio
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | faya
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | sioux lookout
# Processing Record 21 of Set 3 | sawtell
# Processing Record 22 of Set 3 | banmo
# City not found. Skipping...
# Processing Record 23 of Set 3 | kawalu
# Processing Record 24 of Set 3 | fallingbostel
# Processing Record 25 of Set 3 | geraldton
# Processing Record 26 of Set 3 | dikson
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | bonavista
# Processing Record 29 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 3 | pasni
# Processing Record 31 of Set 3 | bontang
# Processing Record 32 of Set 3 | kavaratti
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | santa maria
# Processing Record 35 of Set 3 | snyder
# Processing Record 36 of Set 3 | alofi
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | ha giang
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | cape town
# Processing Record 43 of Set 3 | carballo
# Processing Record 44 of Set 3 | ugoofaaru
# Processing Record 45 of Set 3 | pau brasil
# Processing Record 46 of Set 3 | kasane
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | mount isa
# Processing Record 50 of Set 3 | brae
# Processing Record 1 of Set 4 | xianshuigu
# Processing Record 2 of Set 4 | skjervoy
# Processing Record 3 of Set 4 | teshie
# Processing Record 4 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 5 of Set 4 | dubenskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | grand gaube
# Processing Record 7 of Set 4 | hamilton
# Processing Record 8 of Set 4 | saskylakh
# Processing Record 9 of Set 4 | nanortalik
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | slave lake
# Processing Record 12 of Set 4 | mnogovershinnyy
# Processing Record 13 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 4 | albanel
# Processing Record 15 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 4 | sarakhs
# Processing Record 17 of Set 4 | yar-sale
# Processing Record 18 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | mangochi
# Processing Record 22 of Set 4 | esil
# Processing Record 23 of Set 4 | rawson
# Processing Record 24 of Set 4 | anadyr
# Processing Record 25 of Set 4 | lahaina
# Processing Record 26 of Set 4 | antofagasta
# Processing Record 27 of Set 4 | claremore
# Processing Record 28 of Set 4 | waipawa
# Processing Record 29 of Set 4 | tyret pervaya
# Processing Record 30 of Set 4 | san quintin
# Processing Record 31 of Set 4 | lata
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | pacific grove
# Processing Record 34 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 4 | havoysund
# Processing Record 36 of Set 4 | tiarei
# Processing Record 37 of Set 4 | bagru
# Processing Record 38 of Set 4 | chuy
# Processing Record 39 of Set 4 | vila franca do campo
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | tabou
# Processing Record 42 of Set 4 | lagoa
# Processing Record 43 of Set 4 | vanimo
# Processing Record 44 of Set 4 | ostrovnoy
# Processing Record 45 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 4 | stephenville
# Processing Record 47 of Set 4 | saint-augustin
# Processing Record 48 of Set 4 | abbeville
# Processing Record 49 of Set 4 | ketchikan
# Processing Record 50 of Set 4 | pangody
# Processing Record 1 of Set 5 | rincon
# Processing Record 2 of Set 5 | barwadih
# Processing Record 3 of Set 5 | waitara
# Processing Record 4 of Set 5 | springhill
# Processing Record 5 of Set 5 | balaghat
# Processing Record 6 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 5 | gidole
# Processing Record 8 of Set 5 | tuatapere
# Processing Record 9 of Set 5 | ola
# Processing Record 10 of Set 5 | ambon
# Processing Record 11 of Set 5 | mangrol
# Processing Record 12 of Set 5 | presidencia roque saenz pena
# Processing Record 13 of Set 5 | mwingi
# Processing Record 14 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 5 | bengkulu
# Processing Record 16 of Set 5 | dunedin
# Processing Record 17 of Set 5 | aksay
# Processing Record 18 of Set 5 | talcahuano
# Processing Record 19 of Set 5 | husavik
# Processing Record 20 of Set 5 | dolores
# Processing Record 21 of Set 5 | simbahan
# Processing Record 22 of Set 5 | leningradskiy
# Processing Record 23 of Set 5 | bandarbeyla
# Processing Record 24 of Set 5 | port hardy
# Processing Record 25 of Set 5 | tuchola
# Processing Record 26 of Set 5 | pevek
# Processing Record 27 of Set 5 | khor
# Processing Record 28 of Set 5 | moose factory
# Processing Record 29 of Set 5 | mamlyutka
# Processing Record 30 of Set 5 | pochutla
# Processing Record 31 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 5 | opuwo
# Processing Record 33 of Set 5 | charters towers
# Processing Record 34 of Set 5 | yerbogachen
# Processing Record 35 of Set 5 | bambous virieux
# Processing Record 36 of Set 5 | westport
# Processing Record 37 of Set 5 | cayenne
# Processing Record 38 of Set 5 | la ronge
# Processing Record 39 of Set 5 | nouakchott
# Processing Record 40 of Set 5 | araouane
# Processing Record 41 of Set 5 | byron bay
# Processing Record 42 of Set 5 | igbo ora
# Processing Record 43 of Set 5 | stornoway
# Processing Record 44 of Set 5 | turayf
# Processing Record 45 of Set 5 | kaitangata
# Processing Record 46 of Set 5 | matara
# Processing Record 47 of Set 5 | nyurba
# Processing Record 48 of Set 5 | jiuquan
# Processing Record 49 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 5 | umm kaddadah
# Processing Record 1 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | moron
# Processing Record 4 of Set 6 | aguas vermelhas
# Processing Record 5 of Set 6 | hammerfest
# Processing Record 6 of Set 6 | savannakhet
# Processing Record 7 of Set 6 | grafton
# Processing Record 8 of Set 6 | bambanglipuro
# Processing Record 9 of Set 6 | siavonga
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | kodiak
# Processing Record 12 of Set 6 | qaqortoq
# Processing Record 13 of Set 6 | najran
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | karla
# Processing Record 16 of Set 6 | asau
# Processing Record 17 of Set 6 | keetmanshoop
# Processing Record 18 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 6 | wangou
# Processing Record 20 of Set 6 | tazovskiy
# Processing Record 21 of Set 6 | scarborough
# Processing Record 22 of Set 6 | pimentel
# Processing Record 23 of Set 6 | namibe
# Processing Record 24 of Set 6 | marshall
# Processing Record 25 of Set 6 | naze
# Processing Record 26 of Set 6 | sisimiut
# Processing Record 27 of Set 6 | loiza
# Processing Record 28 of Set 6 | dolinsk
# Processing Record 29 of Set 6 | blind river
# Processing Record 30 of Set 6 | vila velha
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | madisonville
# Processing Record 33 of Set 6 | altay
# Processing Record 34 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 6 | wanganui
# Processing Record 36 of Set 6 | rio brilhante
# Processing Record 37 of Set 6 | rorvik
# Processing Record 38 of Set 6 | soubre
# Processing Record 39 of Set 6 | caravelas
# Processing Record 40 of Set 6 | sorland
# Processing Record 41 of Set 6 | oranjemund
# Processing Record 42 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 6 | algodones
# Processing Record 44 of Set 6 | biak
# Processing Record 45 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 6 | markova
# Processing Record 47 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 48 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 6 | souillac
# Processing Record 50 of Set 6 | neryungri
# Processing Record 1 of Set 7 | chapais
# Processing Record 2 of Set 7 | botou
# Processing Record 3 of Set 7 | yumen
# Processing Record 4 of Set 7 | beringovskiy
# Processing Record 5 of Set 7 | lompoc
# Processing Record 6 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 7 | necochea
# Processing Record 8 of Set 7 | vestmannaeyjar
# Processing Record 9 of Set 7 | tiksi
# Processing Record 10 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 7 | isiolo
# Processing Record 12 of Set 7 | nchelenge
# Processing Record 13 of Set 7 | svetlogorsk
# Processing Record 14 of Set 7 | taltal
# Processing Record 15 of Set 7 | santa rosa de aguan
# Processing Record 16 of Set 7 | varkaus
# Processing Record 17 of Set 7 | pundaguitan
# Processing Record 18 of Set 7 | grand-santi
# Processing Record 19 of Set 7 | dana point
# Processing Record 20 of Set 7 | ceuta
# Processing Record 21 of Set 7 | doctor juan manuel frutos
# Processing Record 22 of Set 7 | jhansi
# Processing Record 23 of Set 7 | erdaojiang
# Processing Record 24 of Set 7 | vardo
# Processing Record 25 of Set 7 | gamba
# Processing Record 26 of Set 7 | lorengau
# Processing Record 27 of Set 7 | saint-philippe
# Processing Record 28 of Set 7 | murgab
# Processing Record 29 of Set 7 | bhimunipatnam
# Processing Record 30 of Set 7 | kimbe
# Processing Record 31 of Set 7 | bella union
# Processing Record 32 of Set 7 | okhotsk
# Processing Record 33 of Set 7 | jamiltepec
# Processing Record 34 of Set 7 | odweyne
# Processing Record 35 of Set 7 | kopavogur
# Processing Record 36 of Set 7 | verkhneye dubrovo
# Processing Record 37 of Set 7 | coquimbo
# Processing Record 38 of Set 7 | altamira
# Processing Record 39 of Set 7 | sorokino
# Processing Record 40 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 7 | jiupu
# Processing Record 42 of Set 7 | belaya gora
# Processing Record 43 of Set 7 | saint-jean-port-joli
# Processing Record 44 of Set 7 | longyan
# Processing Record 45 of Set 7 | te anau
# Processing Record 46 of Set 7 | muroto
# Processing Record 47 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 7 | fairbanks
# Processing Record 49 of Set 7 | bubaque
# Processing Record 50 of Set 7 | les cayes
# Processing Record 1 of Set 8 | ponta delgada
# Processing Record 2 of Set 8 | puerto suarez
# Processing Record 3 of Set 8 | primorsk
# Processing Record 4 of Set 8 | haines junction
# Processing Record 5 of Set 8 | anjozorobe
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | somerville
# Processing Record 8 of Set 8 | creston
# Processing Record 9 of Set 8 | sao miguel do araguaia
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 12 of Set 8 | thinadhoo
# Processing Record 13 of Set 8 | leninskoye
# Processing Record 14 of Set 8 | comodoro rivadavia
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | sonaguera
# Processing Record 17 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 18 of Set 8 | jacobina
# Processing Record 19 of Set 8 | cabo san lucas
# Processing Record 20 of Set 8 | tyrma
# Processing Record 21 of Set 8 | hadejia
# Processing Record 22 of Set 8 | le port
# Processing Record 23 of Set 8 | ambilobe
# Processing Record 24 of Set 8 | shestakovo
# Processing Record 25 of Set 8 | olafsvik
# Processing Record 26 of Set 8 | palasa
# Processing Record 27 of Set 8 | tilichiki
# Processing Record 28 of Set 8 | san miguel
# Processing Record 29 of Set 8 | soyo
# Processing Record 30 of Set 8 | bilma
# Processing Record 31 of Set 8 | kirs
# Processing Record 32 of Set 8 | igarka
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | el reno
# Processing Record 35 of Set 8 | praya
# Processing Record 36 of Set 8 | tukrah
# Processing Record 37 of Set 8 | sembakung
# Processing Record 38 of Set 8 | nea malgara
# Processing Record 39 of Set 8 | verkhnyaya inta
# Processing Record 40 of Set 8 | barra velha
# Processing Record 41 of Set 8 | palazzolo acreide
# Processing Record 42 of Set 8 | korla
# Processing Record 43 of Set 8 | roebourne
# Processing Record 44 of Set 8 | waddan
# Processing Record 45 of Set 8 | calais
# Processing Record 46 of Set 8 | iqaluit
# Processing Record 47 of Set 8 | richards bay
# Processing Record 48 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 8 | braganca
# Processing Record 50 of Set 8 | gorontalo
# Processing Record 1 of Set 9 | saint george
# Processing Record 2 of Set 9 | kaniama
# Processing Record 3 of Set 9 | cap-aux-meules
# Processing Record 4 of Set 9 | zemio
# Processing Record 5 of Set 9 | leh
# Processing Record 6 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 9 | dalvik
# Processing Record 8 of Set 9 | morgan city
# Processing Record 9 of Set 9 | pahrump
# Processing Record 10 of Set 9 | harper
# Processing Record 11 of Set 9 | sabang
# Processing Record 12 of Set 9 | saint anthony
# Processing Record 13 of Set 9 | qingyuan
# Processing Record 14 of Set 9 | nouadhibou
# Processing Record 15 of Set 9 | chimoio
# Processing Record 16 of Set 9 | kulykiv
# Processing Record 17 of Set 9 | ranghulu
# Processing Record 18 of Set 9 | zapolyarnyy
# Processing Record 19 of Set 9 | carberry
# Processing Record 20 of Set 9 | hambantota
# Processing Record 21 of Set 9 | aklavik
# Processing Record 22 of Set 9 | atar
# Processing Record 23 of Set 9 | sur
# Processing Record 24 of Set 9 | prince rupert
# Processing Record 25 of Set 9 | barcelona
# Processing Record 26 of Set 9 | puerto baquerizo moreno
# Processing Record 27 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 28 of Set 9 | gat
# Processing Record 29 of Set 9 | talnakh
# Processing Record 30 of Set 9 | pineville
# Processing Record 31 of Set 9 | walvis bay
# Processing Record 32 of Set 9 | porbandar
# Processing Record 33 of Set 9 | chimore
# Processing Record 34 of Set 9 | ordynskoye
# Processing Record 35 of Set 9 | san carlos de bariloche
# Processing Record 36 of Set 9 | kruisfontein
# Processing Record 37 of Set 9 | peterhead
# Processing Record 38 of Set 9 | lazaro cardenas
# Processing Record 39 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 40 of Set 9 | sept-iles
# Processing Record 41 of Set 9 | mwense
# Processing Record 42 of Set 9 | varzob
# Processing Record 43 of Set 9 | mocuba
# Processing Record 44 of Set 9 | boyuibe
# Processing Record 45 of Set 9 | hualmay
# Processing Record 46 of Set 9 | sao joao da barra
# Processing Record 47 of Set 9 | sao filipe
# Processing Record 48 of Set 9 | srednekolymsk
# Processing Record 49 of Set 9 | nakhon thai
# Processing Record 50 of Set 9 | barra do garcas
# Processing Record 1 of Set 10 | hailun
# Processing Record 2 of Set 10 | tongzi
# Processing Record 3 of Set 10 | shelburne
# Processing Record 4 of Set 10 | prieska
# Processing Record 5 of Set 10 | kalininsk
# Processing Record 6 of Set 10 | zaraza
# Processing Record 7 of Set 10 | jumla
# Processing Record 8 of Set 10 | alexandroupoli
# Processing Record 9 of Set 10 | bokoro
# Processing Record 10 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 10 | sao jose da coroa grande
# Processing Record 12 of Set 10 | cherskiy
# Processing Record 13 of Set 10 | porto velho
# Processing Record 14 of Set 10 | nuuk
# Processing Record 15 of Set 10 | shenjiamen
# Processing Record 16 of Set 10 | sabha
# Processing Record 17 of Set 10 | kankon
# Processing Record 18 of Set 10 | copiapo
# Processing Record 19 of Set 10 | ahipara
# Processing Record 20 of Set 10 | yulara
# Processing Record 21 of Set 10 | mpanda
# Processing Record 22 of Set 10 | alice springs
# Processing Record 23 of Set 10 | padang
# Processing Record 24 of Set 10 | beecher
# Processing Record 25 of Set 10 | saint-pierre
# Processing Record 26 of Set 10 | jardim
# Processing Record 27 of Set 10 | lake city
# Processing Record 28 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 10 | ust-kuyga
# Processing Record 30 of Set 10 | nanakuli
# Processing Record 31 of Set 10 | the valley
# Processing Record 32 of Set 10 | atasu
# Processing Record 33 of Set 10 | pathein
# Processing Record 34 of Set 10 | pindi bhattian
# Processing Record 35 of Set 10 | bethel
# Processing Record 36 of Set 10 | sundumbili
# Processing Record 37 of Set 10 | spoleto
# Processing Record 38 of Set 10 | rivadavia
# Processing Record 39 of Set 10 | winona
# Processing Record 40 of Set 10 | obihiro
# Processing Record 41 of Set 10 | rauma
# Processing Record 42 of Set 10 | lac du bonnet
# Processing Record 43 of Set 10 | recas
# Processing Record 44 of Set 10 | ilulissat
# Processing Record 45 of Set 10 | kudahuvadhoo
# Processing Record 46 of Set 10 | camacha
# Processing Record 47 of Set 10 | bilibino
# Processing Record 48 of Set 10 | bang saphan
# Processing Record 49 of Set 10 | pocinhos
# Processing Record 50 of Set 10 | ayaviri
# Processing Record 1 of Set 11 | mardin
# Processing Record 2 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 3 of Set 11 | skibbereen
# Processing Record 4 of Set 11 | tepla
# Processing Record 5 of Set 11 | herat
# Processing Record 6 of Set 11 | mitsamiouli
# Processing Record 7 of Set 11 | flinders
# Processing Record 8 of Set 11 | porto santo
# Processing Record 9 of Set 11 | aswan
# Processing Record 10 of Set 11 | cah ab
# City not found. Skipping...
# Processing Record 11 of Set 11 | lavrentiya
# Processing Record 12 of Set 11 | cururupu
# Processing Record 13 of Set 11 | salinopolis
# Processing Record 14 of Set 11 | roald
# Processing Record 15 of Set 11 | meulaboh
# Processing Record 16 of Set 11 | kuna
# Processing Record 17 of Set 11 | havelock
# Processing Record 18 of Set 11 | nha trang
# Processing Record 19 of Set 11 | jiwani
# Processing Record 20 of Set 11 | kununurra
# Processing Record 21 of Set 11 | soure
# Processing Record 22 of Set 11 | gunnedah
# Processing Record 23 of Set 11 | plettenberg bay
# Processing Record 24 of Set 11 | beyneu
# Processing Record 25 of Set 11 | grindavik
# Processing Record 26 of Set 11 | avera
# Processing Record 27 of Set 11 | jatai
# Processing Record 28 of Set 11 | ibarra
# Processing Record 29 of Set 11 | irmo
# Processing Record 30 of Set 11 | lokosovo
# Processing Record 31 of Set 11 | karratha
# Processing Record 32 of Set 11 | yazd
# Processing Record 33 of Set 11 | jieshi
# Processing Record 34 of Set 11 | oussouye
# Processing Record 35 of Set 11 | bathsheba
# Processing Record 36 of Set 11 | olbia
# Processing Record 37 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 38 of Set 11 | half moon bay
# Processing Record 39 of Set 11 | kez
# Processing Record 40 of Set 11 | guilin
# Processing Record 41 of Set 11 | banda aceh
# Processing Record 42 of Set 11 | valdosta
# Processing Record 43 of Set 11 | gonen
# Processing Record 44 of Set 11 | leshukonskoye
# Processing Record 45 of Set 11 | gander
# Processing Record 46 of Set 11 | garoua
# Processing Record 47 of Set 11 | mirnyy
# Processing Record 48 of Set 11 | mahon
# Processing Record 49 of Set 11 | inyonga
# Processing Record 50 of Set 11 | yanam
# Processing Record 1 of Set 12 | nishihara
# Processing Record 2 of Set 12 | krasnoselkup
# Processing Record 3 of Set 12 | am timan
# Processing Record 4 of Set 12 | synya
# Processing Record 5 of Set 12 | dezhou
# Processing Record 6 of Set 12 | bonthe
# Processing Record 7 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 12 | san cristobal
# Processing Record 9 of Set 12 | bluefields
# Processing Record 10 of Set 12 | purificacion
# Processing Record 11 of Set 12 | bosaso
# Processing Record 12 of Set 12 | nhulunbuy
# Processing Record 13 of Set 12 | vagur
# Processing Record 14 of Set 12 | zhigansk
# Processing Record 15 of Set 12 | shimanovsk
# Processing Record 16 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 12 | acajutla
# Processing Record 18 of Set 12 | prainha
# Processing Record 19 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 20 of Set 12 | port moresby
# Processing Record 21 of Set 12 | doume
# Processing Record 22 of Set 12 | khawhai
# Processing Record 23 of Set 12 | ierapetra
# Processing Record 24 of Set 12 | ventspils
# Processing Record 25 of Set 12 | honiara
# Processing Record 26 of Set 12 | hilton head island
# Processing Record 27 of Set 12 | wanaka
# Processing Record 28 of Set 12 | luderitz
# Processing Record 29 of Set 12 | yarada
# Processing Record 30 of Set 12 | raudeberg
# Processing Record 31 of Set 12 | inhambane
# Processing Record 32 of Set 12 | mount gambier
# Processing Record 33 of Set 12 | port-cartier
# Processing Record 34 of Set 12 | nea alikarnassos
# Processing Record 35 of Set 12 | segou
# Processing Record 36 of Set 12 | sucua
# Processing Record 37 of Set 12 | kukshi
# Processing Record 38 of Set 12 | el alto
# Processing Record 39 of Set 12 | jibuti
# Processing Record 40 of Set 12 | hervey bay
# Processing Record 41 of Set 12 | ayan
# Processing Record 42 of Set 12 | shimabara
# Processing Record 43 of Set 12 | puerto carreno
# Processing Record 44 of Set 12 | adana
# Processing Record 45 of Set 12 | amahai
# Processing Record 46 of Set 12 | magadan
# Processing Record 47 of Set 12 | susuman
# Processing Record 48 of Set 12 | warrington
# Processing Record 49 of Set 12 | adrar
# Processing Record 50 of Set 12 | north bend
# Processing Record 1 of Set 13 | gallup
# Processing Record 2 of Set 13 | cravo norte
# Processing Record 3 of Set 13 | vostok
# Processing Record 4 of Set 13 | kristiinankaupunki
# Processing Record 5 of Set 13 | guerrero negro
# Processing Record 6 of Set 13 | ngunguru
# Processing Record 7 of Set 13 | nelson bay
# Processing Record 8 of Set 13 | ust-maya
# Processing Record 9 of Set 13 | mount pleasant
# Processing Record 10 of Set 13 | acapulco
# Processing Record 11 of Set 13 | taoudenni
# Processing Record 12 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 13 of Set 13 | fomboni
# Processing Record 14 of Set 13 | andreapol
# Processing Record 15 of Set 13 | muzhi
# Processing Record 16 of Set 13 | kapit
# Processing Record 17 of Set 13 | coracora
# Processing Record 18 of Set 13 | hong gai
# Processing Record 19 of Set 13 | santona
# Processing Record 20 of Set 13 | gravdal
# Processing Record 21 of Set 13 | luganville
# Processing Record 22 of Set 13 | tosya
# Processing Record 23 of Set 13 | manbij
# Processing Record 24 of Set 13 | skuratovskiy
# Processing Record 25 of Set 13 | imbituba
# Processing Record 26 of Set 13 | buraydah
# Processing Record 27 of Set 13 | saryagash
# Processing Record 28 of Set 13 | college
# Processing Record 29 of Set 13 | guarapari
# Processing Record 30 of Set 13 | samarai
# Processing Record 31 of Set 13 | den helder
# Processing Record 32 of Set 13 | rabkavi
# Processing Record 33 of Set 13 | kalmunai
# Processing Record 34 of Set 13 | ballina
# Processing Record 35 of Set 13 | haileybury
# Processing Record 36 of Set 13 | micheweni
# Processing Record 37 of Set 13 | manokwari
# Processing Record 38 of Set 13 | hovd
# Processing Record 39 of Set 13 | visby
# Processing Record 40 of Set 13 | solwezi
# Processing Record 41 of Set 13 | kuytun
# Processing Record 42 of Set 13 | tobermory
# Processing Record 43 of Set 13 | asfi
# Processing Record 44 of Set 13 | ipixuna
# Processing Record 45 of Set 13 | akyab
# Processing Record 46 of Set 13 | terra roxa
# Processing Record 47 of Set 13 | kargasok
# Processing Record 48 of Set 13 | evensk
# Processing Record 49 of Set 13 | monrovia
# Processing Record 50 of Set 13 | batagay-alyta
# Processing Record 1 of Set 14 | abu dhabi
# Processing Record 2 of Set 14 | maykor
# Processing Record 3 of Set 14 | atbasar
# Processing Record 4 of Set 14 | singkang
# Processing Record 5 of Set 14 | mpika
# Processing Record 6 of Set 14 | makakilo city
# Processing Record 7 of Set 14 | tanshui
# City not found. Skipping...
# Processing Record 8 of Set 14 | auki
# Processing Record 9 of Set 14 | kantunilkin
# Processing Record 10 of Set 14 | angoche
# Processing Record 11 of Set 14 | nadvoitsy
# Processing Record 12 of Set 14 | eureka
# Processing Record 13 of Set 14 | duz
# City not found. Skipping...
# Processing Record 14 of Set 14 | lakselv
# Processing Record 15 of Set 14 | oistins
# Processing Record 16 of Set 14 | tortoli
# Processing Record 17 of Set 14 | gushikawa
# Processing Record 18 of Set 14 | saint-joseph
# Processing Record 19 of Set 14 | komsomolskiy
# Processing Record 20 of Set 14 | knysna
# Processing Record 21 of Set 14 | pangnirtung
# Processing Record 22 of Set 14 | tianpeng
# Processing Record 23 of Set 14 | batemans bay
# Processing Record 24 of Set 14 | linjiang
# Processing Record 25 of Set 14 | buala
# Processing Record 26 of Set 14 | kodinsk
# Processing Record 27 of Set 14 | matay
# Processing Record 28 of Set 14 | dondukovskaya
# Processing Record 29 of Set 14 | ridgecrest
# Processing Record 30 of Set 14 | mazagao
# Processing Record 31 of Set 14 | quelimane
# Processing Record 32 of Set 14 | ryuo
# Processing Record 33 of Set 14 | riyadh
# Processing Record 34 of Set 14 | havre-saint-pierre
# Processing Record 35 of Set 14 | zabid
# Processing Record 36 of Set 14 | madang
# Processing Record 37 of Set 14 | paratinga
# Processing Record 38 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 14 | saint austell
# Processing Record 40 of Set 14 | bongandanga
# Processing Record 41 of Set 14 | usinsk
# Processing Record 42 of Set 14 | powell
# Processing Record 43 of Set 14 | teofilo otoni
# Processing Record 44 of Set 14 | shirokiy
# Processing Record 45 of Set 14 | buturlino
# Processing Record 46 of Set 14 | mega
# Processing Record 47 of Set 14 | volkhov
# Processing Record 48 of Set 14 | gornyak
# Processing Record 49 of Set 14 | fukue
# Processing Record 50 of Set 14 | ilo
# Processing Record 1 of Set 15 | ishigaki
# Processing Record 2 of Set 15 | itupiranga
# Processing Record 3 of Set 15 | houma
# Processing Record 4 of Set 15 | cap malheureux
# Processing Record 5 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 15 | ust-nera
# Processing Record 7 of Set 15 | linqiong
# Processing Record 8 of Set 15 | juneau
# Processing Record 9 of Set 15 | zhezkazgan
# Processing Record 10 of Set 15 | lima
# Processing Record 11 of Set 15 | wattegama
# Processing Record 12 of Set 15 | rocky mount
# Processing Record 13 of Set 15 | gizo
# Processing Record 14 of Set 15 | coahuayana
# Processing Record 15 of Set 15 | milos
# Processing Record 16 of Set 15 | antalaha
# Processing Record 17 of Set 15 | chester
# Processing Record 18 of Set 15 | ruzomberok
# Processing Record 19 of Set 15 | ariquemes
# Processing Record 20 of Set 15 | sabzevar
# Processing Record 21 of Set 15 | gazanjyk
# Processing Record 22 of Set 15 | la joya
# Processing Record 23 of Set 15 | daan
# Processing Record 24 of Set 15 | etne
# Processing Record 25 of Set 15 | puerto el triunfo
# Processing Record 26 of Set 15 | kyzyl-suu
# Processing Record 27 of Set 15 | naron
# Processing Record 28 of Set 15 | namatanai
# Processing Record 29 of Set 15 | princeton
# Processing Record 30 of Set 15 | whitehorse
# Processing Record 31 of Set 15 | raga
# Processing Record 32 of Set 15 | ati
# Processing Record 33 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 15 | okha
# Processing Record 35 of Set 15 | sakakah
# Processing Record 36 of Set 15 | port lincoln
# Processing Record 37 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 15 | araceli
# Processing Record 39 of Set 15 | hobyo
# Processing Record 40 of Set 15 | kommunisticheskiy
# Processing Record 41 of Set 15 | grand-lahou
# Processing Record 42 of Set 15 | santa rosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Atuona      PF  -9.8000 -139.0333     78.12        78          37
# 1       Ushuaia      AR -54.8000  -68.3000     55.02        50           0
# 2  Norman Wells      CA  65.2820 -126.8329    -25.56        62          75
# 3      Morehead      US  37.2711  -87.1764     25.11        90         100
# 4      Tasiilaq      GL  65.6145  -37.6368     18.21        59         100
# 5          Hilo      US  19.7297 -155.0900     78.62        80           1
# 6   Provideniya      RU  64.3833 -173.3000     -0.45        64           0
# 7     Busselton      AU -33.6500  115.3333     66.09        55           0
# 8          Mayo      US  38.8876  -76.5119     42.94        94         100
# 9  Puerto Ayora      EC  -0.7393  -90.3518     82.36        86          82
#
#    Wind Speed Current Description
# 0       15.39          light rain
# 1       16.11           clear sky
# 2        8.05       broken clouds
# 3        5.99     overcast clouds
# 4       40.13     overcast clouds
# 5        5.99           clear sky
# 6       14.18           clear sky
# 7        4.83           clear sky
# 8        5.99       moderate rain
# 9        7.00       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
